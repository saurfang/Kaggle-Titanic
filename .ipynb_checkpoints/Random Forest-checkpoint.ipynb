# %%
import pandas as pd
import numpy as np
import csv as csv
from sklearn.ensemble import RandomForestClassifier 

# For .read_csv, always use header=0 when you know row 0 is the header row
df = pd.read_csv('data/train.csv', header=0)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df['Gender'] = pd.factorize(df.Sex)[0]

train_df = df[['Survived', 'Gender', 'Pclass', 'Fare']]
train_df.describe()
# Out:
#          Survived      Gender      Pclass        Fare
# count  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    0.352413    2.308642   32.204208
# std      0.486592    0.477990    0.836071   49.693429
# min      0.000000    0.000000    1.000000    0.000000
# 25%      0.000000    0.000000    2.000000    7.910400
# 50%      0.000000    0.000000    3.000000   14.454200
# 75%      1.000000    1.000000    3.000000   31.000000
# max      1.000000    1.000000    3.000000  512.329200
#
# [8 rows x 4 columns]

# %%
test_df = pd.read_csv('data/test.csv', header=0)
test_df['Gender'] = pd.factorize(test_df.Sex)[0]

# All the missing Fares -> assume median of their respective class
if len(test_df.Fare[ test_df.Fare.isnull() ]) > 0:
    median_fare = np.zeros(3)
    for f in range(0,3):                                              # loop 0 to 2
        median_fare[f] = test_df[ test_df.Pclass == f+1 ]['Fare'].dropna().median()
    for f in range(0,3):                                              # loop 0 to 2
        test_df.loc[ (test_df.Fare.isnull()) & (test_df.Pclass == f+1 ), 'Fare'] = median_fare[f]

ids = test_df['PassengerId'].values

test_df = test_df[['Gender', 'Pclass', 'Fare']]
test_df.describe()
# Out:
#            Gender      Pclass        Fare
# count  418.000000  418.000000  418.000000
# mean     0.363636    2.265550   35.560845
# std      0.481622    0.841838   55.856972
# min      0.000000    1.000000    0.000000
# 25%      0.000000    1.000000    7.895800
# 50%      0.000000    3.000000   14.454200
# 75%      1.000000    3.000000   31.471875
# max      1.000000    3.000000  512.329200
#
# [8 rows x 3 columns]

# %%
train_data = train_df.values
test_data = test_df.values

# %%
print 'Training...'
forest = RandomForestClassifier(n_estimators=100)
forest = forest.fit( train_data[0::,1::], train_data[0::,0] )

print 'Predicting...'
output = forest.predict(test_data).astype(int)


predictions_file = open("myfirstforest.csv", "wb")
open_file_object = csv.writer(predictions_file)
open_file_object.writerow(["PassengerId","Survived"])
open_file_object.writerows(zip(ids, output))
predictions_file.close()
print 'Done.'
# Out:
# Training...
# Predicting...
# Done.
